# %%
# %matplotlib inline
from collections import Counter
import random
import numpy as np
import operator
from scipy.misc import imread
import pandas as pd
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt
import plotly as py
import psycopg2
import seaborn as sbn
import requests
import textatistic
from bs4 import BeautifulSoup

# %%
orders = pd.read_csv('/home/faculty/millbr02/pub/ecomm/orders.csv')

# %%
products = pd.read_csv('/home/faculty/millbr02/pub/ecomm/products.csv')

# %%
aisles = pd.read_csv('/home/faculty/millbr02/pub/ecomm/aisles.csv')

# %%
op = pd.read_csv('/home/faculty/millbr02/pub/ecomm/order_products__prior.csv')

# %%
departments = pd.read_csv('/home/faculty/millbr02/pub/ecomm/departments.csv')

# %%
ot = pd.read_csv('/home/faculty/millbr02/pub/ecomm/order_products__train.csv')

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
op.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
ot.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
product_dict = {}

# %%
t = ot.sort_values('order_id')
first_few = t.head(5000)

# %%
group_1 = first_few.groupby('order_id')

# %%
group_list = list(top_group.groups.keys())

# %%
for item in group_list:
    a = pd.DataFrame(group_1.get_group(item)['product_id'])
    products = []
    for i in range(len(a.index)):
        products.append(a.iloc[i].product_id)
    for item in products:
        if item not in product_dict:
            product_dict[item] = {}
            for other in product_list:
                if other != item:
                    product_dict[item][other] = 1

# %%
print(product_dict)
# Out:
# {32768: {23904: 2, 18432: 2, 45763: 2, 9412: 2, 10631: 2, 46634: 2, 42032: 2, 18926: 2, 46831: 2, 6448: 2, 36372: 2, 7414: 2, 38424: 2, 29101: 2, 41178: 2, 30395: 2}, 8193: {30720: 2, 11777: 2, 40706: 2, 23044: 2, 28934: 2, 10504: 2, 45066: 2, 41047: 2, 43789: 2, 44560: 2, 24850: 2, 24852: 4, 44292: 2, 38944: 2, 25890: 2, 35108: 2, 36389: 2, 2086: 2, 48679: 2, 44402: 2, 29487: 2, 39984: 2, 47156: 2, 